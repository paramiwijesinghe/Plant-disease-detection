# %% [markdown]
# # Testing

# %%
from keras.models import load_model
import cv2
import numpy as np

# Load the test set
X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

# Load the entire model including architecture and weights
model = load_model('my_model.keras')

# Define the category dictionary (0: 'Diseased', 1: 'Healthy')
category_dict = {0: 'Diseased', 1: 'Healthy'}

# Define the input shape expected by the model
input_shape = (150, 150, 3)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Initialize variables for summary
correct_predictions = 0

# Function to predict and display results
def predict_and_display(img, true_label, model, category_dict, input_shape):
    global correct_predictions
    test_img = cv2.resize(img, (input_shape[1], input_shape[0]))
    test_img_rgb = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
    test_img_rgb = test_img_rgb / 255.0
    test_img_rgb = np.expand_dims(test_img_rgb, axis=0)
    
    results = model.predict(test_img_rgb)
    
    label = np.argmax(results, axis=1)[0]
    acc = int(np.max(results, axis=1)[0] * 100)
    predicted_category = category_dict[label]
    true_category = category_dict[true_label]

    if acc < 50:
        predicted_category = 'NONE'
    else:
        if label == true_label:
            correct_predictions += 1

    font_scale = 0.4
    thickness = 1
    text_margin = 2

    # Display true label
    cv2.putText(img, f"True: {true_category}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), thickness)
    # Display predicted label below the true label
    cv2.putText(img, f"Pred: {predicted_category}", (20, 70), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), thickness)
    # Display accuracy below the predicted label
    cv2.putText(img, str(acc) + '%', (20, 110 + 2 * text_margin), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), thickness)

    height, width, _ = img.shape
    aspect_ratio = width / height
    display_img = cv2.resize(img, (800, int(800 / aspect_ratio)))
    cv2.imshow('LIVE', display_img)
    
    return true_category, predicted_category

# Display predictions on test images
for i in range(len(X_test)):
    img = (X_test[i] * 255).astype(np.uint8)  # Convert back to original scale
    true_label = np.argmax(y_test[i])  # Get the true label from one-hot encoding
    true_category, predicted_category = predict_and_display(img, true_label, model, category_dict, input_shape)
    
    print(f"Sample {i+1}: True Label: {true_category}, Predicted Label: {predicted_category}")
    
    k = cv2.waitKey(0)
    if k == 27:  # ESC key
        cv2.destroyAllWindows()
        break  # Break the loop if ESC key is pressed

# Print summary
total_samples = len(X_test)
accuracy = (correct_predictions / total_samples) * 100

print(f"Total samples: {total_samples}")
print(f"Correct predictions: {correct_predictions}")
print(f"Overall accuracy: {accuracy:.2f}%")
# Out:
# WARNING:tensorflow:From E:\Anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From E:\Anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From E:\Anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From E:\Anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From E:\Anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 14s 279ms/step - loss: 0.2055 - accuracy: 0.9310
# Test Loss: 0.20550104975700378
# Test Accuracy: 0.931034505367279
# 1/1 [==============================] - 0s 348ms/step
# Sample 1: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 215ms/step
# Sample 2: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 73ms/step
# Sample 3: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 103ms/step
# Sample 4: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 28ms/step
# Sample 5: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 30ms/step
# Sample 6: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 221ms/step
# Sample 7: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 47ms/step
# Sample 8: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 29ms/step
# Sample 9: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 28ms/step
# Sample 10: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 29ms/step
# Sample 11: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 80ms/step
# Sample 12: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 30ms/step
# Sample 13: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 34ms/step
# Sample 14: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 118ms/step
# Sample 15: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 45ms/step
# Sample 16: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 40ms/step
# Sample 17: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 43ms/step
# Sample 18: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 47ms/step
# Sample 19: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 30ms/step
# Sample 20: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 57ms/step
# Sample 21: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 30ms/step
# Sample 22: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 28ms/step
# Sample 23: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 29ms/step
# Sample 24: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 34ms/step
# Sample 25: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 29ms/step
# Sample 26: True Label: Healthy, Predicted Label: NONE
# 1/1 [==============================] - 0s 30ms/step
# Sample 27: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 29ms/step
# Sample 28: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 30ms/step
# Sample 29: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 29ms/step
# Sample 30: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 35ms/step
# Sample 31: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 34ms/step
# Sample 32: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 30ms/step
# Sample 33: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 31ms/step
# Sample 34: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 31ms/step
# Sample 35: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 27ms/step
# Sample 36: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 29ms/step
# Sample 37: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 32ms/step
# Sample 38: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 34ms/step
# Sample 39: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 32ms/step
# Sample 40: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 64ms/step
# Sample 41: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 58ms/step
# Sample 42: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 62ms/step
# Sample 43: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 41ms/step
# Sample 44: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 32ms/step
# Sample 45: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 30ms/step
# Sample 46: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 32ms/step
# Sample 47: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 31ms/step
# Sample 48: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 61ms/step
# Sample 49: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 56ms/step
# Sample 50: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 52ms/step
# Sample 51: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 40ms/step
# Sample 52: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 37ms/step
# Sample 53: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 33ms/step
# Sample 54: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 38ms/step
# Sample 55: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 44ms/step
# Sample 56: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 29ms/step
# Sample 57: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 39ms/step
# Sample 58: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 30ms/step
# Sample 59: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 38ms/step
# Sample 60: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 30ms/step
# Sample 61: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 67ms/step
# Sample 62: True Label: Healthy, Predicted Label: NONE
# 1/1 [==============================] - 0s 59ms/step
# Sample 63: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 42ms/step
# Sample 64: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 62ms/step
# Sample 65: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 34ms/step
# Sample 66: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 36ms/step
# Sample 67: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 52ms/step
# Sample 68: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 52ms/step
# Sample 69: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 39ms/step
# Sample 70: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 33ms/step
# Sample 71: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 60ms/step
# Sample 72: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 29ms/step
# Sample 73: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 35ms/step
# Sample 74: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 28ms/step
# Sample 75: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 45ms/step
# Sample 76: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 30ms/step
# Sample 77: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 34ms/step
# Sample 78: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 55ms/step
# Sample 79: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 37ms/step
# Sample 80: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 65ms/step
# Sample 81: True Label: Healthy, Predicted Label: Diseased
# 1/1 [==============================] - 0s 31ms/step
# Sample 82: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 59ms/step
# Sample 83: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 32ms/step
# Sample 84: True Label: Diseased, Predicted Label: Healthy
# 1/1 [==============================] - 0s 66ms/step
# Sample 85: True Label: Diseased, Predicted Label: Diseased
# 1/1 [==============================] - 0s 64ms/step
# Sample 86: True Label: Healthy, Predicted Label: Healthy
# 1/1 [==============================] - 0s 31ms/step
# Sample 87: True Label: Diseased, Predicted Label: Healthy
# Total samples: 87
# Correct predictions: 63
# Overall accuracy: 72.41%
